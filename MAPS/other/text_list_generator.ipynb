# %%
import pickle, pprint
import math
import numpy as np

# %%
pkl_file = open('/fast/gmooers/MAPS/Coord_List.pkl', 'rb')
text_list = pickle.load(pkl_file)
pkl_file.close()

# %%
print(len(text_list))
# Out:
# 109

# %%
np.savetxt('Coordinates_List.txt', text_list,  fmt='%f', delimiter=',')
print('Text file Generated')
# Out:
# Text file Generated

# %%
for i in range(len(text_list)):
    print(text_list[i])
# Out:
# [12.5, -19.89473684210526]
# [22.5, -19.89473684210526]
# [45.0, -19.89473684210526]
# [107.5, -19.89473684210526]
# [287.5, -19.89473684210526]
# [292.5, -19.89473684210526]
# [295.0, -19.89473684210526]
# [302.5, -19.89473684210526]
# [305.0, -19.89473684210526]
# [310.0, -19.89473684210526]
# [312.5, -19.89473684210526]
# [315.0, -19.89473684210526]
# [317.5, -19.89473684210526]
# [10.0, -18.0]
# [32.5, -18.0]
# [45.0, -18.0]
# [47.5, -18.0]
# [82.5, -18.0]
# [285.0, -18.0]
# [287.5, -18.0]
# [290.0, -18.0]
# [292.5, -18.0]
# [297.5, -18.0]
# [300.0, -18.0]
# [305.0, -18.0]
# [310.0, -18.0]
# [317.5, -18.0]
# [10.0, -16.10526315789474]
# [32.5, -16.10526315789474]
# [37.5, -16.10526315789474]
# [65.0, -16.10526315789474]
# [127.5, -16.10526315789474]
# [282.5, -16.10526315789474]
# [287.5, -16.10526315789474]
# [290.0, -16.10526315789474]
# [320.0, -16.10526315789474]
# [15.0, -14.21052631578948]
# [17.5, -14.21052631578948]
# [20.0, -14.21052631578948]
# ...

# %%
numbers = np.array(text_list)
np.save('/fast/gmooers/MAPS/numbers.npy', numbers)
