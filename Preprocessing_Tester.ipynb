# %%
# !python3 preprocessing_CRM.py -c pp_config/W_MAPS.yml
# Out:
# 03/30/2020 02:59:57 PM Preprocess training dataset
# 03/30/2020 02:59:57 PM Start preprocessing file /fast/gmooers/Preprocessed_Data/Small_W_MAPS/000_train.nc
# 03/30/2020 02:59:57 PM Reading input files
# 03/30/2020 02:59:57 PM Reading input file /DFS-L/DATA/pritchard/gmooers/Workflow/MAPS/SPCAM/Small_Sample/New_SPCAM5/archive/TimestepOutput_Neuralnet_SPCAM_216/atm/hist/TimestepOutput_Neuralnet_SPCAM_216.cam.h1.2008-10-11-00000.nc
# 03/30/2020 02:59:57 PM Crop levels
# 03/30/2020 02:59:57 PM Create stacked dataarray
# These time steps are cut: []
# 03/30/2020 02:59:57 PM Stack and reshape dataarray
# 03/30/2020 02:59:57 PM Save dataarray as /fast/gmooers/Preprocessed_Data/Small_W_MAPS/000_train.nc
# 03/30/2020 03:00:43 PM Done!
#
# end preprocess
#
# 03/30/2020 03:00:43 PM Shuffle training dataset
# ...

# %%
# !python3 precprocessing_land.py -c pp_config/SPCAM5_Test.yml
# Out:
# 03/30/2020 03:29:35 PM Preprocess training dataset
# 03/30/2020 03:29:35 PM Start preprocessing file /fast/gmooers/Preprocessed_Data/SPCAM5_Comp/000_train.nc
# 03/30/2020 03:29:35 PM Reading input files
# 03/30/2020 03:29:35 PM Reading input file /DFS-L/DATA/pritchard/gmooers/Workflow/SPCAM_DATA/SPCAM5/2018_Validation/TimestepOutput_Neuralnet_SPCAM_216.cam.h1.2018-06-27-72000.nc
# 03/30/2020 03:29:36 PM Crop levels
# 03/30/2020 03:29:36 PM Create stacked dataarray
# These time steps are cut: []
# 03/30/2020 03:29:36 PM Stack and reshape dataarray
# 03/30/2020 03:29:36 PM Save dataarray as /fast/gmooers/Preprocessed_Data/SPCAM5_Comp/000_train.nc
# 03/30/2020 03:29:39 PM Done!
#
# end preprocess
#
# 03/30/2020 03:29:39 PM Shuffle training dataset
# 03/30/2020 03:29:39 PM Start shuffling /fast/gmooers/Preprocessed_Data/SPCAM5_Comp/000_train.nc into /fast/gmooers/Preprocessed_Data/SPCAM5_Comp/000_train_shuffle.nc. Open and create datasets.
# 03/30/2020 03:29:39 PM Shuffle!
# ...
