# %%
import pprint, pickle

# %%
print('Start')
pkl_file = open('001_toms_scaling.pkl', 'rb')
data1 = pickle.load(pkl_file)
pkl_file.close()
print('Pickle 1')

print('Start')
pkl_file = open('002_pnas_scaling.pkl', 'rb')
data2 = pickle.load(pkl_file)
pkl_file.close()
print('Pickle 2')

print('Start')
pkl_file = open('pnas_exact.pkl', 'rb')
data3 = pickle.load(pkl_file)
pkl_file.close()
print('Pickle 3')
# Out:
# Start
# Pickle 1
# Start
# Pickle 2
# Start
# Pickle 3

# %%
print(type(data1))
# Out:
# <class 'dict'>

# %%
print(data1)
# Out:
# {'PHQ': array([7.0811688e+07, 1.3074195e+08, 2.1416968e+08, 3.0895507e+08,
#        3.8762448e+08, 4.4520454e+08, 4.4321338e+08, 3.6317286e+08,
#        4.2725360e+08, 5.0264170e+08, 5.9133267e+08, 6.9567149e+08,
#        8.1842150e+08, 9.6283104e+08, 1.1327212e+09, 1.3325868e+09,
#        1.5677202e+09, 1.8443410e+09, 2.1697718e+09, 2.1706406e+09,
#        1.9922205e+09, 1.6811768e+09, 1.2494753e+09, 7.2336192e+08,
#        6.7863757e+08, 6.2842387e+08, 5.7302957e+08, 5.1279936e+08,
#        4.4820157e+08, 3.7970438e+08], dtype=float32), 'PHCLDLIQ': array([7.0811688e+07, 1.3074195e+08, 2.1416968e+08, 3.0895507e+08,
#        3.8762448e+08, 4.4520454e+08, 4.4321338e+08, 3.6317286e+08,
#        4.2725360e+08, 5.0264170e+08, 5.9133267e+08, 6.9567149e+08,
#        8.1842150e+08, 9.6283104e+08, 1.1327212e+09, 1.3325868e+09,
#        1.5677202e+09, 1.8443410e+09, 2.1697718e+09, 2.1706406e+09,
#        1.9922205e+09, 1.6811768e+09, 1.2494753e+09, 7.2336192e+08,
# ...
